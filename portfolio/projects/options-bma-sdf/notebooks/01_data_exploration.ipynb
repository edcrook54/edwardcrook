# %% [markdown]
# # 01 — Data Exploration
#
# Options data source evaluation and initial filtering (ATM, shortest maturity > 1 month, price > $5).

# %%
import sys
sys.path.append('..')

from portfolio_common.plotting import set_style
set_style()
